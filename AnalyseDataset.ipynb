# %% [markdown]
# <h1>First of all let's start with analyzing dataset.</h1>

# %%
# %pip install pandas numpy ydata_profiling scikit-learn
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: ydata_profiling in ./.venv/lib/python3.12/site-packages (4.12.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (1.13.1)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (2.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in ./.venv/lib/python3.12/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (4.67.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (4.4.1)
# Requirement already satisfied: imagehash==4.3.1 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in ./.venv/lib/python3.12/site-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in ./.venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata_profiling) (1.7.0)
# Requirement already satisfied: pillow in ./.venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata_profiling) (11.0.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (3.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./.venv/lib/python3.12/site-packages (from numba<1,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./.venv/lib/python3.12/site-packages (from pydantic>=2->ydata_profiling) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.venv/lib/python3.12/site-packages (from pydantic>=2->ydata_profiling) (4.12.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in ./.venv/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in ./.venv/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (3.4.2)
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_10_9_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 36.5 MB/s eta 0:00:00 0:00:01
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.5.2 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os
from ydata_profiling import ProfileReport

bus_stops_data = pd.read_excel('data/FLEXI_bus_stops.xls')
trip_data = pd.read_excel('data/FLEXI_trip_data.xls')

# %%
report_file = 'bus_stops_data.html'

if not os.path.exists(report_file):
    profile = ProfileReport(bus_stops_data, title = 'FLEXI Bus Stops - Report')

    profile.to_file('bus_stops_data_report_1.html')
    profile.dump('bus_stops_data_report_1')

profile = ProfileReport().load('bus_stops_data_report_1.pp')
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-11-14 19:00:27.018344&quot;&gt;&lt;title&gt;FLEXI Bus Stops - Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
report_file = 'trip_data.html'

if not os.path.exists(report_file):
    profile = ProfileReport(trip_data, title = 'FLEXI Trips - Report')

    profile.to_file('trip_data_report_1.html')
    profile.dump('trip_data_report_1')

profile = ProfileReport().load('trip_data_report_1.pp')
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-11-14 19:01:23.926066&quot;&gt;&lt;title&gt;FLEXI Trips - Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# ***As we can see here there are multiple types of objects so first of all we need to encode them to numerical values in order to work on them easily.***

# %%
bus_stops_data.info()

bus_stops_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   df_index   70 non-null     int64
#  1   name       70 non-null     object
#  2   district   70 non-null     object
#  3   latitude   70 non-null     float64
#  4   longitude  70 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.9+ KB
#    df_index                           name  district   latitude  longitude
# 0         0               Kinding, Bahnhof   Kinding  48.992168  11.377365
# 1         1              Enkering, Maibaum  Enkering  48.992498  11.363953
# 2         2        Enkering, Feuerwehrhaus  Enkering  48.993652  11.361228
# 3         3  Kinding, Beilngrieser Stra√üe   Kinding  49.002445  11.390002
# 4         4            Kinding, Marktplatz   Kinding  49.000562  11.382790

# %% [markdown]
# ***The reason to drop district is that information is given under the 'name' column.***

# %%
from sklearn.preprocessing import OneHotEncoder

bus_stops_data_encoded = bus_stops_data.copy()

bus_stops_data_encoded.drop("district", inplace=True, axis=1)


encoder = OneHotEncoder()

encoded_name = encoder.fit_transform(bus_stops_data_encoded[['name']])

encoded_name_df = pd.DataFrame(encoded_name.toarray(), columns=encoder.get_feature_names_out(['name']))

bus_stops_data_encoded = pd.concat([bus_stops_data_encoded.drop('name', axis=1), encoded_name_df], axis=1)

bus_stops_data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 73 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   df_index                                            70 non-null     int64
#  1   latitude                                            70 non-null     float64
#  2   longitude                                           70 non-null     float64
#  3   name_Amtmannsdorf                                   70 non-null     float64
#  4   name_Arnbuch                                        70 non-null     float64
#  5   name_Aschbuch, Altenzeller Weg                      70 non-null     float64
#  6   name_Aschbuch, Lindenstra√üe                        70 non-null     float64
#  7   name_Aschbuch, Waldsiedlung                         70 non-null     float64
#  8   name_Badanhausen, Fischerstra√üe                    70 non-null     float64
#  9   name_Beilngries, An der Leitn                       70 non-null     float64
#  10  name_Beilngries, Bauhofstra√üe                      70 non-null     float64
#  11  name_Beilngries, Deutscher Hof                      70 non-null     float64
#  12  name_Beilngries, Eichstaetter Strasse / Tankstelle  70 non-null     float64
#  13  name_Beilngries, Frauenkirche                       70 non-null     float64
#  14  name_Beilngries, Freibad                            70 non-null     float64
#  15  name_Beilngries, Gaisbergweg                        70 non-null     float64
#  16  name_Beilngries, Gartenstra√üe                      70 non-null     float64
#  17  name_Beilngries, Hafen                              70 non-null     float64
#  18  name_Beilngries, Hirschberger stra√üe               70 non-null     float64
#  19  name_Beilngries, Kanalsiedlung                      70 non-null     float64
#  20  name_Beilngries, Kelheimer Stra√üe                  70 non-null     float64
#  21  name_Beilngries, Neumarkter Stra√üe                 70 non-null     float64
#  22  name_Beilngries, Ottmaringer Stra√üe                70 non-null     float64
#  23  name_Beilngries, Rathaus                            70 non-null     float64
#  24  name_Beilngries, Ringstrasse                        70 non-null     float64
#  25  name_Beilngries, Utzmuehlweg                        70 non-null     float64
#  26  name_Beilngries, Volksfestplatz                     70 non-null     float64
#  27  name_Beilngries, ZOB                                70 non-null     float64
#  28  name_Beilngries, Zinnerhof                          70 non-null     float64
#  29  name_Betriebshof Hengl                              70 non-null     float64
#  30  name_Biberbach                                      70 non-null     float64
#  31  name_Eglofsdorf, B 299                              70 non-null     float64
#  32  name_Eglofsdorf, Ortskern                           70 non-null     float64
#  33  name_Enkering, Feuerwehrhaus                        70 non-null     float64
#  34  name_Enkering, Maibaum                              70 non-null     float64
#  35  name_Goesselthal                                    70 non-null     float64
#  36  name_Grampersdorf, Gewerbegebiet                    70 non-null     float64
#  37  name_Grampersdorf, Kirchstra√üe                     70 non-null     float64
#  38  name_Grampersdorf, Landstrasse                      70 non-null     float64
#  39  name_Haunstetten, Gewerbegebiet                     70 non-null     float64
#  40  name_Haunstetten, Kirche                            70 non-null     float64
#  41  name_Haunstetten, Kuehlerstrasse                    70 non-null     float64
#  42  name_Hirschberg, Dorfkapelle                        70 non-null     float64
#  43  name_Hirschberg, Fuerstenstrasse                    70 non-null     float64
#  44  name_Irfersdorf, Am Kirchplatz                      70 non-null     float64
#  45  name_Kaldorf                                        70 non-null     float64
#  46  name_Kevenhuell, Kirche                             70 non-null     float64
#  47  name_Kinding, Bahnhof                               70 non-null     float64
#  48  name_Kinding, Beilngrieser Stra√üe                  70 non-null     float64
#  49  name_Kinding, Marktplatz                            70 non-null     float64
#  50  name_Kinding, Schule                                70 non-null     float64
#  51  name_Kirchanhausen                                  70 non-null     float64
#  52  name_Kirchbuch                                      70 non-null     float64
#  53  name_Kottingwoerth, Alte Salzstrasse                70 non-null     float64
#  54  name_Kottingwoerth, Dietfurter Strasse              70 non-null     float64
#  55  name_Kottingwoerth, Im Hub                          70 non-null     float64
#  56  name_Kottingwoerth, Muehlleite                      70 non-null     float64
#  57  name_Kratzmuehle, Seerestaurant                     70 non-null     float64
#  58  name_Leising                                        70 non-null     float64
#  59  name_Leising, ABG Tagungszentrum                    70 non-null     float64
#  60  name_Litterzhofen, Kirche                           70 non-null     float64
#  61  name_Neuzell, Feuerwehr                             70 non-null     float64
#  62  name_Oberndorf, Feuerwehr                           70 non-null     float64
#  63  name_Oberndorf, Kirche                              70 non-null     float64
#  64  name_Paulushofen, Am Haar                           70 non-null     float64
#  65  name_Paulushofen, Dorfstra√üe                       70 non-null     float64
#  66  name_Paulushofen, Spielplatz                        70 non-null     float64
#  67  name_Pfraundorf, Dorfplatz                          70 non-null     float64
#  68  name_Plankstetten, Biberbacher Stra√üe              70 non-null     float64
#  69  name_Unteremmendorf, Wendeschleife                  70 non-null     float64
#  70  name_Wiesenhofen, Kirche                            70 non-null     float64
#  71  name_Wolfsbuch, Am Schacher                         70 non-null     float64
#  72  name_Wolfsbuch, Fuchsengasse                        70 non-null     float64
# dtypes: float64(72), int64(1)
# memory usage: 40.1 KB

# %%
trip_data_encoded = trip_data.copy()

trip_data_encoded.info()

trip_data_encoded['is_trip_completed'] = trip_data_encoded['Passenger status'].map({"Trip completed": 1, "Cancelled": 0})

trip_data_encoded.drop('Passenger status', inplace=True, axis=1)

trip_data_encoded.info()

trip_data_encoded.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3838 entries, 0 to 3837
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Booking ID           3838 non-null   int64
#  1   Status               3838 non-null   object
#  2   Passenger status     3838 non-null   object
#  3   Passengers           3838 non-null   int64
#  4   Pickup ID            3838 non-null   int64
#  5   Dropoff ID           3838 non-null   int64
#  6   Actual Pickup Time   3838 non-null   datetime64[ns]
#  7   Actual Dropoff Time  3838 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(4), object(2)
# memory usage: 240.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3838 entries, 0 to 3837
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Booking ID           3838 non-null   int64
#  1   Status               3838 non-null   object
#  2   Passengers           3838 non-null   int64
#  3   Pickup ID            3838 non-null   int64
#  4   Dropoff ID           3838 non-null   int64
#  5   Actual Pickup Time   3838 non-null   datetime64[ns]
#  6   Actual Dropoff Time  3838 non-null   datetime64[ns]
#  7   is_trip_completed    3838 non-null   int64
# dtypes: datetime64[ns](2), int64(5), object(1)
# memory usage: 240.0+ KB
#    Booking ID               Status  Passengers  Pickup ID  Dropoff ID  \
# 0      252392            Validated           2         55          70
# 1      253212  Cancelled by client           1         40           0
# 2      253369  Cancelled by client           3         66           0
# 3      253808  Cancelled by driver           2         30           0
# 4      253782            Validated           2         40          21
#
#    Actual Pickup Time Actual Dropoff Time  is_trip_completed
# 0 2024-09-01 08:01:00 2024-09-01 08:17:00                  1
# 1 2024-09-01 08:18:00 2024-09-01 08:34:00                  0
# 2 2024-09-01 08:46:00 2024-09-01 09:09:00                  0
# 3 2024-09-01 08:56:00 2024-09-01 09:09:00                  0
# 4 2024-09-01 09:14:00 2024-09-01 09:25:00                  1

# %%
encoder = OneHotEncoder()

encoded_status = encoder.fit_transform(trip_data_encoded[['Status']])

encoded_name_df = pd.DataFrame(encoded_status.toarray(), columns=encoder.get_feature_names_out(['Status']))

trip_data_encoded = pd.concat([trip_data_encoded.drop('Status', axis=1), encoded_name_df], axis=1)

trip_data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3838 entries, 0 to 3837
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Booking ID                       3838 non-null   int64
#  1   Passengers                       3838 non-null   int64
#  2   Pickup ID                        3838 non-null   int64
#  3   Dropoff ID                       3838 non-null   int64
#  4   Actual Pickup Time               3838 non-null   datetime64[ns]
#  5   Actual Dropoff Time              3838 non-null   datetime64[ns]
#  6   is_trip_completed                3838 non-null   int64
#  7   Status_Cancelled by call center  3838 non-null   float64
#  8   Status_Cancelled by client       3838 non-null   float64
#  9   Status_Cancelled by driver       3838 non-null   float64
#  10  Status_Changed by admin          3838 non-null   float64
#  11  Status_Changed by client         3838 non-null   float64
#  12  Status_Validated                 3838 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(5)
# memory usage: 389.9 KB
